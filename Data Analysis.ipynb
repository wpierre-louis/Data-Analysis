# %% [markdown]
# # Data Analysis with National Hospital Data
#
# Welcome! This ipython notebook will take you through the basics of data analysis in application to national medical data. With this data visualization the hope is to reflect patterns both good and bad in healthcare and see why do some trends, or lack thereof, exist. From this information, professionals in the healthcare field can account for these shortcomings and brainstorm new solutions for better patient care.
#
# Data URL: https://www.cdc.gov/nchs/data-visualization/natality-trends/

# %%
#below are the packages that are imported for this analysis process

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib as mpl

# %%
#pd.read_csv("") calls pandas to read the data and sort them into columns and rows

# %%
data= pd.read_csv('Births and General Fertility Rates US.csv')

# %%
#The downloaded data is set to the variable- data, which is a much faster and simpler way of calling the information you 
#need. The data is shown below into the various columns and rows. Each different csv file will be set to a different 
#variable length.

# %%
#It is necessary to check your csv files to make sure there are not any blank or not applicable values. In addition, 
#accounting for any values that are extreamly high/low that can skew the data. Some data scientist remove these values 
#altogether and for any blank values they are substituted with the mean values.

# %%
#Calling the data is a good way to see how many rows/columns there are, what are their names, and from there you can prompt
#a series of other functions. For example, you can see how pandas reads certain values by using the type() function.

# %%
data
# Out:
#      Year Birth Number  General Fertility Rate  Crude Birth Rate
# 0    2015    3,978,497                    62.5              12.4
# 1    2014    3,988,076                    62.9              12.5
# 2    2013    3,932,181                    62.5              12.4
# 3    2012    3,952,841                    63.0              12.6
# 4    2011    3,953,590                    63.2              12.7
# 5    2010    3,999,386                    64.1              13.0
# 6    2009    4,130,665                    66.2              13.5
# 7    2008    4,247,694                    68.1              14.0
# 8    2007    4,316,233                    69.3              14.3
# 9    2006    4,265,555                    68.6              14.3
# 10   2005    4,138,349                    66.7              14.0
# 11   2004    4,112,052                    66.4              14.0
# 12   2003    4,089,950                    66.1              14.1
# ...

# %%
#This graph is the first of several and also the most general. The slope represents the general U.S fertility rate from 
#1909-2015. Clearly there was a largedrop in the 20s to the 30s which is around the great depression era and also 
#consistently drops from the 60s into the 80s. The first oral contraceptive was approved in the U.S in 1960 but access was 
#limited. Over the years more women and/or married couple had access and rights to birth control. This data visualization 
#goes to show that historical trends can be reflected in numbers if collected properly and documented efficently.

# %%
plt.plot(data.Year, data["General Fertility Rate"])
plt.title("General U.S Fertility Rate from 1909-2015")
plt.xlabel("Year")
plt.ylabel("Fertility Rate")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#This second graph demonstrates the crude birth rate from 1909-2015 across all races. A crude birth rate is the total number
#live births per 1,000 in a population in a year or period. With this data set the period is per year.

# %%
plt.plot(data.Year, data["Crude Birth Rate"])
plt.title("Crude Birth Rate from 1909-2015")
plt.xlabel("Year")
plt.ylabel("Crude Birth Rate")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Below is the third graph that shows relatioship between the birth numbers from 1909-2015. The y-axis is dense with the 
#something known as "ticks". The reason why is because matplotlib is reading the numbers as a series rather than a float.
#I.e 597,218 is read as a series while 597218 can be read as a float or integer. Once this issue is rectified then the graph 
#will rearrange away from its linear form into a more staggered, horizontal sloped line.

# %%
plt.plot(data.Year, data["Birth Number"])
plt.title("Birth Number from 1909-2015")
plt.xlabel("Year")
plt.ylabel("Birth Number")
plt.style.use("seaborn")

plt.show()

# %% [markdown]
# # Natality Measures for Females by Race

# %%
#pandas reading in another csv file

# %%
data2= pd.read_csv("Natality Measures.csv")

# %%
data2
# Out:
#      Year                Race Live Births  Birth Rate  Fertility Rate
# 0    2015           All races   3,978,497        12.4            62.5
# 1    2014           All races   3,988,076        12.5            62.9
# 2    2013           All races   3,932,181        12.4            62.5
# 3    2012           All races   3,952,841        12.6            63.0
# 4    2011           All races   3,953,590        12.7            63.2
# 5    2010           All races   3,999,386        13.0            64.1
# 6    2009           All races   4,130,665        13.5            66.2
# 7    2008           All races   4,247,694        14.0            68.1
# 8    2007           All races   4,316,233        14.3            69.3
# 9    2006           All races   4,265,555        14.3            68.6
# 10   2005           All races   4,138,349        14.0            66.7
# 11   2004           All races   4,112,052        14.0            66.4
# ...

# %%
#The format of (dataname).(column_name) will yield all the values or strings that are under that column. The second 
#dataset shows the birth rates of different races so below will be true and false statements that will yield all the 
#related data to the prompt.

# %%
allraces= data2[data2.Race=="All races"]

# %%
allraces
# Out:
#     Year       Race Live Births  Birth Rate  Fertility Rate
# 0   2015  All races   3,978,497        12.4            62.5
# 1   2014  All races   3,988,076        12.5            62.9
# 2   2013  All races   3,932,181        12.4            62.5
# 3   2012  All races   3,952,841        12.6            63.0
# 4   2011  All races   3,953,590        12.7            63.2
# 5   2010  All races   3,999,386        13.0            64.1
# 6   2009  All races   4,130,665        13.5            66.2
# 7   2008  All races   4,247,694        14.0            68.1
# 8   2007  All races   4,316,233        14.3            69.3
# 9   2006  All races   4,265,555        14.3            68.6
# 10  2005  All races   4,138,349        14.0            66.7
# 11  2004  All races   4,112,052        14.0            66.4
# 12  2003  All races   4,089,950        14.1            66.1
# 13  2002  All races   4,021,726        14.0            65.0
# 14  2001  All races   4,025,933        14.1            65.1
# ...

# %%
plt.plot(allraces.Year, allraces["Birth Rate"], marker='o', color="black")
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.title("Birth Rate for All Races")
plt.show()

# %%
data2.Race
# Out:
# 0               All races
# 1               All races
# 2               All races
# 3               All races
# 4               All races
# 5               All races
# 6               All races
# 7               All races
# 8               All races
# 9               All races
# 10              All races
# 11              All races
# 12              All races
# 13              All races
# 14              All races
# 15              All races
# 16              All races
# 17              All races
# 18              All races
# 19              All races
# 20              All races
# 21              All races
# 22              All races
# 23              All races
# 24              All races
# 25              All races
# 26              All races
# 27              All races
# 28              All races
# 29              All races
#               ...
# 392    Non-Hispanic Black
# 393    Non-Hispanic Black
# 394    Non-Hispanic Black
# 395    Non-Hispanic White
# 396    Non-Hispanic White
# ...

# %%
#The line below essentially says that: in the column Race of data2, all the strings that do not equal "Non-Hispanic Black"
#are false and will be void because it is now set equal to data2.Race. The format (datasetname)["(column_name)""] will give
#you all the values for the column. This will be the y axis and the year will be the x axis.

# %%
black= data2[data2.Race=="Non-Hispanic Black"]

# %%
#all_races

# %%
black
# Out:
#      Year                Race Live Births  Birth Rate  Fertility Rate
# 368  1989  Non-Hispanic Black     611,269        22.8            84.8
# 369  1990  Non-Hispanic Black     661,701        23.0            89.0
# 370  1991  Non-Hispanic Black     666,758        22.4            87.0
# 371  1992  Non-Hispanic Black     657,450        21.6            84.5
# 372  1993  Non-Hispanic Black     641,273        20.7            81.5
# 373  1994  Non-Hispanic Black     619,198        19.5            77.5
# 374  1995  Non-Hispanic Black     587,781        18.2            72.8
# 375  1996  Non-Hispanic Black     578,099        17.6            70.7
# 376  1997  Non-Hispanic Black     581,431        17.4            70.3
# 377  1998  Non-Hispanic Black     593,127        17.5            70.9
# 378  1999  Non-Hispanic Black     588,981        17.1            69.9
# 379  2000  Non-Hispanic Black     604,346        17.3            71.4
# ...

# %%
#The x axis (year) and the y axis (birth rate) are plotted on the graph. Each data point is noted by a "o" type figure and 
#the graph color is selected as magenta. The title is reflective of what the data demonstrates and the axes are labeled.
#Similar processes will be done to the other graphs but with appropriate substitution.

# %%
plt.plot(black.Year, black["Birth Rate"], marker='o', color="magenta" )
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.title("Birth Rate for Non-Hispanic Black Females")
plt.show()

# %%
white= data2[data2.Race=="Non-Hispanic White"]

# %%
white
# Out:
#      Year                Race Live Births  Birth Rate  Fertility Rate
# 395  1989  Non-Hispanic White   2,526,367        14.2            60.5
# 396  1990  Non-Hispanic White   2,626,500        14.4            62.8
# 397  1991  Non-Hispanic White   2,589,878        13.9            60.9
# 398  1992  Non-Hispanic White   2,527,207        13.4            60.0
# 399  1993  Non-Hispanic White   2,472,031        13.1            58.9
# 400  1994  Non-Hispanic White   2,438,855        12.8            58.2
# 401  1995  Non-Hispanic White   2,382,638        12.5            57.5
# 402  1996  Non-Hispanic White   2,358,989        12.3            57.1
# 403  1997  Non-Hispanic White   2,333,363        12.2            56.8
# 404  1998  Non-Hispanic White   2,361,462        12.2            57.6
# 405  1999  Non-Hispanic White   2,346,450        12.1            57.7
# 406  2000  Non-Hispanic White   2,362,968        12.2            58.5
# ...

# %%
plt.plot(white.Year, white["Birth Rate"], marker='o', )
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.title("Birth Rate for Non-Hispanic White Females")
plt.show()

# %%
native= data2[data2.Race=="American Indian or Alaska Native"]

# %%
native
# Out:
#      Year                              Race Live Births  Birth Rate  \
# 56   2015  American Indian or Alaska Native      44,299         9.7
# 57   2014  American Indian or Alaska Native      44,928         9.9
# 58   2013  American Indian or Alaska Native      45,991        10.3
# 59   2012  American Indian or Alaska Native      46,093        10.5
# 60   2011  American Indian or Alaska Native      46,419        10.7
# 61   2010  American Indian or Alaska Native      46,760        11.0
# 62   2009  American Indian or Alaska Native      48,665        11.8
# 63   2008  American Indian or Alaska Native      49,537        12.4
# 64   2007  American Indian or Alaska Native      49,443        12.9
# 65   2006  American Indian or Alaska Native      47,721        12.9
# 66   2005  American Indian or Alaska Native      44,813        12.6
# 67   2004  American Indian or Alaska Native      43,927        12.8
# 68   2003  American Indian or Alaska Native      43,052        13.0
# ...

# %%
plt.plot(native.Year, native["Birth Rate"], marker='o', color="blue")
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.title("Birth Rate for American Indian or Alaska Native Females")
plt.show()

# %%
asian_islander= data2[data2.Race=="Asian or Pacific Islander"]

# %%
asian_islander
# Out:
#      Year                       Race Live Births  Birth Rate  Fertility Rate
# 112  2015  Asian or Pacific Islander     281,264        14.0            58.5
# 113  2014  Asian or Pacific Islander     282,723        14.6            60.7
# 114  2013  Asian or Pacific Islander     265,673        14.3            59.2
# 115  2012  Asian or Pacific Islander     272,802        15.1            62.2
# 116  2011  Asian or Pacific Islander     253,915        14.5            59.9
# 117  2010  Asian or Pacific Islander     246,886        14.5            59.2
# 118  2009  Asian or Pacific Islander     251,089        15.1            61.3
# 119  2008  Asian or Pacific Islander     253,185        15.7            63.3
# 120  2007  Asian or Pacific Islander     254,488        16.4            65.3
# 121  2006  Asian or Pacific Islander     241,045        16.0            63.7
# 122  2005  Asian or Pacific Islander     231,108        15.9            63.0
# ...

# %%
plt.plot(asian_islander.Year, asian_islander["Birth Rate"], marker='o', color="green" )
plt.xlabel("Year")
plt.ylabel("Birth Rate")
plt.title("Birth Rate for Asian or Pacific Islander Females")
plt.show()

# %%
#Each plt.plot will be put on one graph because it is within one coding cell. It is also because they all have similar
#parameters for the x axis, years. The x and y labels are the same but the title changes and a legend is added so it is able
#to be read easier. Another line of code was added (plt.legend(loc="best")) that automatic chooses the best location for 
#the legend depending on the position of the graph.

# %%
plt.plot(allraces.Year, allraces["Birth Rate"], marker='o', color="black")
plt.plot(black.Year, black["Birth Rate"], marker='o', color="magenta" )
plt.plot(white.Year, white["Birth Rate"], marker='o', )
plt.plot(native.Year, native["Birth Rate"], marker='o', color="blue")
plt.plot(asian_islander.Year, asian_islander["Birth Rate"], marker='o', color="green" )

plt.xlabel("Year")
plt.ylabel("Birth Rate")

plt.legend(["All Races Birth Rate", "Black Birth Rate","White Birth Rate","American Native/Alaska Native Birth Rate",
            "Asian or Pacific Islander Birth Rate"])

plt.legend(loc="best")

plt.title("Birth Rates of Non-Hispanic Races")
# Out:
# Text(0.5, 1.0, 'Birth Rates of Non-Hispanic Races')
